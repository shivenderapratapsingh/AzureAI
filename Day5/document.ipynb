# %%
import requests,os
import time
from dotenv import load_dotenv

load_dotenv()

endpoint =os.getenv("endpoint")
key = os.getenv("key")

url = endpoint + "formrecognizer/documentModels/prebuilt-invoice:analyze?api-version=2023-07-31"


headers = {
    "Ocp-Apim-Subscription-Key": key,
    "Content-Type": "image/jpeg"
}

# step 1: send invoice
with open("receipt.jpeg", "rb") as f:
    data = f.read()

response = requests.post(url, headers=headers, data=data)

print("Step 1 Status:", response.status_code)
print("Headers:", response.headers)

# check if request accepted
if response.status_code == 202:
    
    result_url = response.headers["operation-location"]

    # wait for processing
    time.sleep(5)

    # step 2: get result
    result = requests.get(result_url,
                          headers={"Ocp-Apim-Subscription-Key": key})

    print("Final Result:")
    print(result.json())

else:
    print("Error:")
    print(response.text)
# Out:
# Step 1 Status: 202
# Headers: {'Content-Length': '0', 'Operation-Location': 'https://shivendera.cognitiveservices.azure.com/formrecognizer/documentModels/prebuilt-invoice/analyzeResults/32787dd7-6af9-4914-a467-a91f0232fb25?api-version=2023-07-31', 'x-envoy-upstream-service-time': '78', 'apim-request-id': '32787dd7-6af9-4914-a467-a91f0232fb25', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'x-content-type-options': 'nosniff', 'x-ms-region': 'Korea Central', 'Date': 'Fri, 10 Apr 2026 09:10:51 GMT'}
# Final Result:
# {'status': 'succeeded', 'createdDateTime': '2026-04-10T09:10:51Z', 'lastUpdatedDateTime': '2026-04-10T09:10:55Z', 'analyzeResult': {'apiVersion': '2023-07-31', 'modelId': 'prebuilt-invoice', 'stringIndexType': 'textElements', 'content': "SCHOOL OF COMPUTING SCIENCE & ENGINEERING\nGRADE AT\nPlot No. 2, Sector-17A, Yamuna Expressway, Greater Noida, Gautam buddh Nagar, Uttar Pradesh, India ,\nOpposite, Buddha International Circuit, Sector 17A, Greater Noida , Uttar Pradesh , India - 203201\nPhone : 0120-4806827,0120-4806824Fax : 0120-4806888Email: support@galgotiasuniversity.edu.in .\nRECEIPT\nStudent Copy\nReceipt No\n2024-2025/GU//338386\nAdmission No.\nDeposit Date\n05/04/2024\nStudent Name\nAR\nSemester\nSem IV\nBachelor of Technology in\nProgram\nComputer Science and\nFee Category\nGeneral\nEngineering\nFather's Name\nMother's Name\nSession\n2022-2023\nRoll. No.\n22131010841\nAcademic Year\n2023-2024\nSr. No.\nParticulars\nReceived(Rs.)\n1\nEXAM FEE\n10000.00\n2\nCAUTION MONEY- NON REFUNDABLE\n2000.00\n3\nTUITION FEE\n83000.00\nTotal\n95000.00\nPayment Details\nChq/DD\nMode\nRemarks\nChq/DD No\nChq/DD Date\nBank(Student Amount\nBank)\nPaytm\nPaytm|2024-04-05\n17:09:39|17123171791710624961\n05/04/2024\n95000.00\nRemark :\nBachelor of Technology in Computer Science and Engineering 05/04/2024\nWE THANKFULLY ACKNOWLEDGE THE RECEIPT OF (95000.00)\n[Rupees Ninety Five Thousands Only.]\nNote :\ni) Fees once paid shall not be refunded.\nii) The validity of receipt is subject to realization of Cheque/Demand.\niii) This is computer generated receipt, no signature required.\n(Accountant/Account Officer)\nFor School of Computing Science & Engineering\nReceipt Generated By :", 'pages': [{'pageNumber': 1, 'angle': 0, 'width': 1239, 'height': 1216, 'unit': 'pixel', 'words': [{'content': 'SCHOOL', 'polygon': [517, 25, 603, 25, 604, 46, 517, 46], 'confidence': 0.995, 'span': {'offset': 0, 'length': 6}}, {'content': 'OF', 'polygon': [610, 25, 638, 25, 638, 46, 611, 46], 'confidence': 0.996, 'span': {'offset': 7, 'length': 2}}, {'content': 'COMPUTING', 'polygon': [645, 25, 771, 25, 772, 47, 645, 46], 'confidence': 0.993, 'span': {'offset': 10, 'length': 9}}, {'content': 'SCIENCE', 'polygon': [782, 25, 872, 25, 872, 46, 783, 46], 'confidence': 0.993, 'span': {'offset': 20, 'length': 7}}, {'content': '&', 'polygon': [880, 25, 894, 25, 894, 46, 881, 46], 'confidence': 0.962, 'span': {'offset': 28, 'length': 1}}, {'content': 'ENGINEERING', 'polygon': [904, 25, 1050, 26, 1050, 45, 904, 46], 'confidence': 0.991, 'span': {'offset': 30, 'length': 11}}, {'content': 'GRADE', 'polygon': [271, 77, 291, 77, 292, 131, 271, 132], 'confidence': 0.556, 'span': {'offset': 42, 'length': 5}}, {'content': 'AT', 'polygon': [302, 76, 332, 76, 333, 130, 303, 131], 'confidence': 0.515, 'span': {'offset': 48, 'length': 2}}, {'content': 'Plot', 'polygon': [430, 99, 456, 99, 456, 117, 430, 117], 'confidence': 0.991, 'span': {'offset': 51, 'length': 4}}, {'content': 'No.', 'polygon': [459, 99, 484, 99, 484, 117, 460, 117], 'confidence': 0.993, 'span': {'offset': 56, 'length': 3}}, {'content': '2,', 'polygon': [488, 99, 501, 99, 501, 117, 488, 117], 'confidence': 0.948, 'span': {'offset': 60, 'length': 2}}, {'content': 'Sector-17A,', 'polygon': [505, 99, 583, 99, 584, 117, 505, 117], 'confidence': 0.972, 'span': {'offset': 63, 'length': 11}}, {'content': 'Yamuna', 'polygon': [587, 99, 642, 99, 643, 117, 587, 117], 'confidence': 0.993, 'span': {'offset': 75, 'length': 6}}, {'content': 'Expressway,', 'polygon': [646, 99, 730, 99, 730, 117, 646, 117], 'confidence': 0.968, 'span': {'offset': 82, 'length': 11}}, {'content': 'Greater', 'polygon': [733, 99, 786, 99, 786, 117, 733, 117], 'confidence': 0.992, 'span': {'offset': 94, 'length': 7}}, {'content': 'Noida,', 'polygon': [790, 99, 835, 99, 835, 117, 790, 117], 'confidence': 0.983, 'span': {'offset': 102, 'length': 6}}, {'content': 'Gautam', 'polygon': [839, 99, 889, 99, 889, 117, 839, 117], 'confidence': 0.995, 'span': {'of ...

# %%
result_json = result.json()

fields = result_json["analyzeResult"]["documents"][0]["fields"]

structured_output = {
    "VendorName": fields.get("VendorName", {}),
    "CustomerName": fields.get("CustomerName", {}),
    "InvoiceId": fields.get("InvoiceId", {}),
    "InvoiceDate": fields.get("InvoiceDate", {}),
    "DueDate": fields.get("DueDate", {}),
    "TotalAmount": fields.get("InvoiceTotal", {}),
    "SubTotal": fields.get("SubTotal", {}),
    "Tax": fields.get("TotalTax", {}),
    "Items": fields.get("Items", {})
}

import json
print(json.dumps(structured_output, indent=2))

# %%
import json

result_json = result.json()
# print(result_json.analyzeResult.pages[0].words)
for word in result_json['analyzeResult']['pages'][0]['words']:
    print(word["content"])

# print(json.dumps(result_json, indent=2))
# Out:
# SCHOOL
# OF
# COMPUTING
# SCIENCE
# &
# ENGINEERING
# GRADE
# HAT
# Plot
# No.
# 2,
# Sector-17A,
# Yamuna
# Expressway,
# Greater
# Noida,
# Gautam
# buddh
# Nagar,
# Uttar
# Pradesh,
# India
# ,
# Opposite,
# Buddha
# International
# Circuit,
# Sector
# 17A,
# Greater
# Noida
# ,
# Uttar
# Pradesh
# ,
# India
# -
# 203201
# Phone
# :
# 0120-4806827,0120-4806824Fax
# :
# 0120-4806888Email:
# support@galgotiasuniversity.edu.in
# .
# RECEIPT
# Student
# Copy
# Receipt
# No
# 2024-2025/GU//338386
# Admission
# No.
# 22SCSE1010799
# Deposit
# Date
# 05/04/2024
# Student
# Name
# SATYAM
# KUMAR
# Semester
# Sem
# IV
# Bachelor
# of
# Technology
# in
# Program
# Computer
# Science
# and
# Fee
# Category
# General
# Engineering
# Father's
# Name
# Shambhu
# Thakur
# Mother's
# Name
# Bhagyawati
# Devi
# Session
# 2022-2023
# Roll.
# No.
# 22131010841
# Academic
# Year
# 2023-2024
# Sr.
# No.
# Particulars
# Received(Rs.)
# 1
# EXAM
# FEE
# 10000.00
# 2
# CAUTION
# MONEY-
# NON
# REFUNDABLE
# 2000.00
# 3
# TUITION
# FEE
# 83000.00
# Total
# 95000.00
# Payment
# Details
# Chq/DD
# Mode
# Remarks
# Chq/DD
# No
# Chq/DD
# Date
# Bank(Student
# Amount
# Bank)
# Paytm
# Paytm|2024-04-05
# 17:09:39|17123171791710624961
# 17123171791710624961
# 05/04/2024
# 95000.00
# Remark
# :
# Bachelor
# of
# Technology
# in
# Computer
# Science
# and
# Engineering
# 05/04/2024
# WE
# THANKFULLY
# ACKNOWLEDGE
# THE
# RECEIPT
# OF
# (95000.00)
# [Rupees
# Ninety
# Five
# Thousands
# Only.]
# Note
# :
# i)
# Fees
# once
# paid
# shall
# not
# be
# refunded.
# ii)
# The
# validity
# of
# receipt
# is
# subject
# to
# realization
# of
# Cheque/Demand.
# iii)
# This
# is
# computer
# generated
# receipt,
# no
# signature
# required.
# (Accountant/Account
# Officer)
# For
# School
# of
# Computing
# Science
# &
# Engineering
# Receipt
# Generated
# By
# :
